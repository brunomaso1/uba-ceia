# %% [markdown]
# Topicos de los que hablar:
# - Poner información del dominio + variables.
# - Tipo de analisis de datos: Análisis predictivo. (https://campusposgrado.fi.uba.ar/pluginfile.php/27294/mod_resource/content/0/ceia_AdD_clase1.pdf)
# - Framework de datos elegidos: CRISP-DM (https://www.ibm.com/docs/es/spss-modeler/saas?topic=dm-crisp-help-overview) en combinación con esto un pipeline de machine learning (https://www.ibm.com/topics/machine-learning-pipeline)
# CRISP-ML(Q) -> https://arxiv.org/pdf/2003.05155.pdf | https://ml-ops.org/content/crisp-ml | https://www.datacamp.com/blog/machine-learning-lifecycle-explained | https://medium.com/@acharya4398/crisp-ml-cross-industry-standard-process-for-machine-learning-5892e0d3f8cf
# - Ver tema de pre-condiciones de los modelos (assumptions) https://www.kdnuggets.com/2021/02/machine-learning-assumptions.html
# https://www.kaggle.com/code/prashant111/logistic-regression-classifier-tutorial/notebook Assmptions of logistic regression
# - Analizar la correlación de RISK_MM. Después de sacarla justificar con este comentario https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package/discussion/78316
# - Probar con modelos de si llovió hoy va a llover mañana. O random chioce.
# - Necesidad de mantener un orden de tiempo en la variable Date (separar en tres columnas) (discretizar) Extraccion de características temporales
# - Estación del año??
#
# - Missing values (MCAR?)
# - Outliers? (si hay se utiliza la mediana) -> Censored (CAP)
# - Correlacion
# - Transformations
# - Feature enginering
# - Feature scaling
#
# - Cuando se analiza estadísticamente los datos, nombrar si hay algo raro con los mínimos y máximos.
# - Los valores estadísticos siempre tomarlos del conjunto de entrenamiento. En la imputación por ejemplo, utilizar la mediana de entrenamiento para imputar en test. Imputación con datos categóricos el valor más frecuente. Moda.
#
# - Luego de la imputación y manejo de outliers, hacer nuevamente un chequeo estadístico de los datos.
# - Realizar tablas al final de las secciones (Resumen)

# %% [markdown]
# Indice:
# - Metodología
# - Tipo de análisis de datos (objetivo)
# - CRISP-ML(Q)
#     - Entendimiento del negocio y los datos (Business and Data Understanding)
#         - Identificar:
#             - Alcance
#             - Criterios de éxito (KPI)
#             - Criterios de verificación de los datos.
#             - Objetivo: Factibilidad del proyecto
#             - ML Canvas
#             - Identificar stakeholders
#             - Restricciones
#             - Disponibilidad de los datos
#             - Requerimientos de generación de datos
#             - Requerimientos de calidad de datos.
#             - Identificar atributos de calidad más importantes
#     - Ingeniería de datos (Data Engineering - Data preparation)
#         - Data exploration
#             - Momentos
#             - Valores faltantes
#             - Outliers
#             - Correlación entre datos
#         - Data selection
#         - Data clearing
#             - Detección de errores y corrección de errores
#         - Feature engineering
#             - Imputación de los datos
#         - Data augmentation
#         - Utilizando: Metodos de filtrado, wrapper o embedeed.
#         - Se descartan datos que no cumplen con los requerimientos de calidad de los datos.
#         - Desbalanceo de datos (oversampling - under-sampling)
#         - Data standarization
#         - Creación de pipelines de datos
#     - Ingeniería de modelos de aprendizaje automático (Machine Learning Model Engineering)
#         - Depende del problema de negocio
#         - Modelos:
#
#         - Adjornarse a los atributos de calidad.
#         - Seleccion del modelo, especialización del modelo, tareas de entrenamiento del modelo, compresión del modelo, ensambles.
#         - Optimización del modelo (feature selection)
#         - Tabla para especificar cada metadata de los modelos: Algoritmo, entrenamiento, validación y testeo de los datos, hiper-parámetros, ambiente
#         - Especificar asumciones del modelo (se puede utilizar GPT para preguntar precondiciones de los datos para cada modelo)
#         - Empaquetar en el pipeline
#     - Aseguramiento de la calidad  para aplicaciones de aprendizaje automático (Quality Assurance for Machine Learning Applicactions)
#         - Offline testing.
#         - Se valida con el conjunto test.
#         - Se chequea la robustez del modelo utilizando ruido o datos incorrectos
#         - Se pueden mostrar reportes de explicabilidad.
#         - Se ve si se cumplieron con KPIs, objetivos, criterios de éxito
#     - Despliegue (Deployment)
#         - Integración
#         - Definición del hardware
#         - Evaluación del modelo en producción
#         - Pre-producción
#         - Tests A/B, online testing
#         - Aceptación de usuarios y test de usabilidad
#         - Plan de recuperación de desastres.
#         - CD/CI
#     - Monitoreo y mantenimiento (Monitoring and Maintenance)
#         - Continued model evaluation
#         - Plan de mantenimiento programado/Plan de emergencias
#
# - Mejora continua (futuro)
#     - Completar fases faltantes
#     - Realizar proceso completo

# %% [markdown]
# TODOs:
#
# - Ver tema de las referencias.
# - Cambiar todo a español (las palabras en ingles pnerlas en cursiva si no se quiere/puede)
# - Graficos:
# > Cinco cosas importantes para los gráficos (que puedan responder):
# > - Que (que se está midiendo - caracterizando -)
# > - Como (tiene que ver con la unidad de medida)
# > - Cuando (si hay un período de tiempo en ese estudio)
# > - Donde
# > - Fuente (fuente: ej: datos de elaboración propias)

# %% [markdown]
# Analizar en los duplicados si antes no hay que asignar np.nan

# %% [markdown]
# Comentar código faltante y resovler el tema de funciones auxiliares

# %% [markdown]
# Arreglar la grafica de ubicaciones y tiempo (la de Juan)

# %% [markdown]
# Solucionar error de geopandas que explotó todo

# %% [markdown]
# Achicar gráficos
